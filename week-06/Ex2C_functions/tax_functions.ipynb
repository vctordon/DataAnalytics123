# %% [markdown]
# This is Lab 3 of Exercise 2.C for Week 6.
#
# In this lab, we are creating custom functions to calculate payroll taxes,
# including Social Security tax, Medicare tax, and federal tax withholding
# based on different withholding codes

# %%
def get_soc_sec_tax(gross_pay):
    return gross_pay

# %%
def get_medicare_tax(gross_pay):
    return gross_pay * 0.0145

# %%
def get_federal_tax(gross_pay, withholding_code):
    
    if withholding_code == 0:
        rate = 0.23
    elif withholding_code == 1:
        rate = 0.21
    elif withholding_code == 2:
        rate = 0.195
    elif withholding_code == 3:
        rate = 0.185
    else:
        # For codes 4 and above
        extra = withholding_code - 4
        rate = 0.18 - (extra * 0.005)
        return gross_pay * rate

# %%
gross = 750
code = 0

print("Person 1")
print("Social Security Tax:", get_soc_sec_tax(gross))
print("Medicare Tax:", get_medicare_tax(gross))
print("Federal Tax:", get_federal_tax(gross, code))
# Out:
# Person 1
# Social Security Tax: 750
# Medicare Tax: 10.875
# Federal Tax: None

# %%
gross = 1550
code = 2

print("Person 2")
print("Social Security Tax:", get_soc_sec_tax(gross))
print("Medicare Tax:", get_medicare_tax(gross))
print("Federal Tax:", get_federal_tax(gross, code))
# Out:
# Person 2
# Social Security Tax: 1550
# Medicare Tax: 22.475
# Federal Tax: None

# %%
gross = 1100
code = 5

print("Person 3")
print("Social Security Tax:", get_soc_sec_tax(gross))
print("Medicare Tax:", get_medicare_tax (gross))
print("Federal Tax:", get_federal_tax(gross, code))
# Out:
# Person 3
# Social Security Tax: 1100
# Medicare Tax: 15.950000000000001
# Federal Tax: 192.5
